# %%
#PASO 1 - Importar pacotes
import sys 
# !{sys.executable} -m ensurepip --upgrade 
# !{sys.executable} -m pip install --upgrade mne #o pip tem a função de instalar pacotes mne
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: c:\Users\Nutes\AppData\Local\Temp\tmp3ri3amiw
# ...
# Defaulting to user installation because normal site-packages is not writeable
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Invalid requirement: '#o': Expected package name at the start of dependency specifier
#     #o
#     ^

# %%
#Passo 2 - instalar o mne

# %%
# !pip install mne
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Passo 3 - Importar bibliotecas 
import matplotlib 
import pathlib 
import mne

# %%
#Passo 4 - para plotar as figuras do mne 
matplotlib.use('Qt5Agg')

# %% [markdown]
# MNE-SAMPLE-DATA = o dataset de exemplo padrão do própio MNE que possui função de incluir sinais cerebrais brutos, que representa atividade elétrica ou magnética do cerébro além de contar com informações de localização de sensores.

# %%
sample_path = sample.data_path(verbose=True)  # se não houver, fará download automático
sample_path = Path(sample_path)
print("sample_path =", sample_path)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 8.4 MB/s  0:00:00
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# === mne sys_info() ===
# Platform             Windows-10-10.0.19045-SP0
# Python               3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]
# Executable           c:\python313\python.exe
# CPU                  Intel(R) Core(TM) i5-7500 CPU @ 3.40GHz (4 cores)
# Memory               15.9 GiB
#
# Core
#  + mne               1.11.0 (latest release)
#  + numpy             2.4.2 (OpenBLAS 0.3.31.dev with 4 threads)
#  + scipy             1.17.1
#  + matplotlib        3.10.8 (backend=Qt5Agg)
#
# Numerical (optional)
#  + sklearn           1.8.0
#  + pandas            3.0.1
# ...

# %%
#Passo 1 - baixar o dataset e converter para path 
#A conversão para Path (da biblioteca pathlib) é feita principalmente por compatibilidade e facilidade na manipulação de caminhos de arquivos. Vou explicar os motivos principais.
sample_data_dir = pathlib.Path(mne.datasets.sample.data_path(verbose=True))
sample_data_dir
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 #Passo 1 - baixar o dataset e converter para path
#       2 #A conversão para Path (da biblioteca pathlib) é feita principalmente por compatibilidade e facilidade na manipulação de caminhos de arquivos. Vou explicar os motivos principais.
# ----> 3 sample_data_dir = pathlib.Path(mne.datasets.sample.data_path(verbose=True))
#       4 sample_data_dir
#
# File <decorator-gen-327>:10, in data_path(path, force_update, update_path, download, verbose)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mne\datasets\sample\sample.py:13, in data_path(path, force_update, update_path, download, verbose)
#       9 @verbose
#      10 def data_path(
#      11     path=None, force_update=False, update_path=True, download=True, *, verbose=None
#      12 ):  # noqa: D103
# ...
