# %%
# %pip install mne
# %pip install numpy
# %pip install pandas
# %pip install matplotlib
# Out:
# Requirement already satisfied: mne in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (1.11.0)
# Requirement already satisfied: decorator in c:\users\nutes\appdata\roaming\python\python312\site-packages (from mne) (5.2.1)
# Requirement already satisfied: jinja2 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from mne) (3.1.6)
# Requirement already satisfied: lazy-loader>=0.3 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from mne) (0.4)
# Requirement already satisfied: matplotlib>=3.8 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from mne) (3.10.8)
# Requirement already satisfied: numpy<3,>=1.26 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from mne) (2.4.2)
# Requirement already satisfied: packaging in c:\users\nutes\appdata\roaming\python\python312\site-packages (from mne) (26.0)
# Requirement already satisfied: pooch>=1.5 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from mne) (1.9.0)
# Requirement already satisfied: scipy>=1.11 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from mne) (1.17.1)
# Requirement already satisfied: tqdm in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from mne) (4.67.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.8->mne) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.8->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.8->mne) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.8->mne) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.8->mne) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.8->mne) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nutes\appdata\roaming\python\python312\site-packages (from matplotlib>=3.8->mne) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\nutes\appdata\roaming\python\python312\site-packages (from pooch>=1.5->mne) (4.9.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from pooch>=1.5->mne) (2.32.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from jinja2->mne) (3.0.3)
# Requirement already satisfied: colorama in c:\users\nutes\appdata\roaming\python\python312\site-packages (from tqdm->mne) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\nutes\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.8->mne) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2026.2.25)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (2.4.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nutes\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\nutes\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\nutes\appdata\roaming\python\python312\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\nutes\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nutes\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\nutes\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mne
import os
import numpy as np
import matplotlib

# %%
pip install PySide6
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting PySide6
#   Using cached pyside6-6.10.2-cp39-abi3-win_amd64.whl.metadata (5.5 kB)
# Collecting shiboken6==6.10.2 (from PySide6)
#   Using cached shiboken6-6.10.2-cp39-abi3-win_amd64.whl.metadata (2.6 kB)
# Collecting PySide6_Essentials==6.10.2 (from PySide6)
#   Using cached pyside6_essentials-6.10.2-cp39-abi3-win_amd64.whl.metadata (3.8 kB)
# Collecting PySide6_Addons==6.10.2 (from PySide6)
#   Using cached pyside6_addons-6.10.2-cp39-abi3-win_amd64.whl.metadata (4.2 kB)
# Using cached pyside6-6.10.2-cp39-abi3-win_amd64.whl (569 kB)
# Using cached pyside6_addons-6.10.2-cp39-abi3-win_amd64.whl (164.7 MB)
# Using cached pyside6_essentials-6.10.2-cp39-abi3-win_amd64.whl (74.5 MB)
# Using cached shiboken6-6.10.2-cp39-abi3-win_amd64.whl (1.2 MB)
# Installing collected packages: shiboken6, PySide6_Essentials, PySide6_Addons, PySide6
#
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    -------------------- ------------------- 2/4 [PySide6_Addons]
#    ------------------------------ --------- 3/4 [PySide6]
#    ---------------------------------------- 4/4 [PySide6]
#
# Successfully installed PySide6-6.10.2 PySide6_Addons-6.10.2 PySide6_Essentials-6.10.2 shiboken6-6.10.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
matplotlib.use('QtAgg')

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3],[4,5,6])
plt.show()
# Out:
# Channels marked as bad:
# none
# Channels marked as bad:
# none
# Channels marked as bad:
# none

# %%
rawEEG = mne.io.read_raw_edf('EDF_EEG.edf', preload=True)
rawEEG.plot()
# Out:
# Extracting EDF parameters from EDF_EEG.edf...
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 197375  =      0.000 ...   770.996 secs...
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 1920x1017 with 4 Axes>

# %%
rawEEG.plot(block=False, duration=10.0, title='raw EEG data')
# Out:
# <MNEBrowseFigure size 1920x1017 with 4 Axes>

# %%
rawEEG.filter(.1,30)
rawEEG.plot(block=False, duration=10.0, title='Filtered EEG data')
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 8449 samples (33.004 s)
# <MNEBrowseFigure size 1920x1017 with 4 Axes>

# %%
rawEEG.info
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fp2, F7, F3, Fz, F4, F8, T7, C3, Cz, C4, T8, P7, P3, Pz, ...
#  chs: 19 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: 2023-04-08 19:44:04 UTC
#  nchan: 19
#  projs: []
#  sfreq: 256.0 Hz
#  subject_info: <subject_info | his_id: X, sex: 0, last_name: Anonymous, birthday: 1951-05-13>
# >

# %%
EEGFiltered = mne.io.read_raw_fif('EEGFiltered.fif', preload=True)
# Out:
# Opening raw data file EEGFiltered.fif...
# Isotrak not found
#     Range : 0 ... 197375 =      0.000 ...   770.996 secs
# Ready.
# Reading 0 ... 197375  =      0.000 ...   770.996 secs...
# C:\Users\Nutes\AppData\Local\Temp\ipykernel_6836\1059112096.py:1: RuntimeWarning: This filename (EEGFiltered.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   EEGFiltered = mne.io.read_raw_fif('EEGFiltered.fif', preload=True)

# %%
from mne.preprocessing import ICA

# %%
montage = mne.channels.make_standard_montage('standard_1020')

# %%
rawEEG.set_montage(montage)
# Out:
# <RawEDF | EDF_EEG.edf, 19 x 197376 (771.0 s), ~28.6 MiB, data loaded>

# %%
ICAComponents = ICA(15)

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\nutes\appdata\roaming\python\python313\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\nutes\appdata\roaming\python\python313\site-packages (from scikit-learn) (2.4.2)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\nutes\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\nutes\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\nutes\appdata\roaming\python\python313\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install sklearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sklearn
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
import sklearn

# %%
ICAComponents.fit(rawEEG)
# Out:
# Fitting ICA to data using 19 channels (please be patient, this may take a while)
# C:\Users\Nutes\AppData\Local\Temp\ipykernel_6836\3171822909.py:1: RuntimeWarning: The data has not been high-pass filtered. For good ICA performance, it should be high-pass filtered (e.g., with a 1.0 Hz lower bound) before fitting ICA.
#   ICAComponents.fit(rawEEG)
# Selecting by number: 15 components
# Fitting ICA took 3.5s.
# <ICA | raw data decomposition, method: fastica (fit in 34 iterations on 197376 samples), 15 ICA components (19 PCA components available), channel types: eeg, no sources marked for exclusion>

# %%
ICAComponents.plot_components()
# Out:
# <MNEFigure size 975x731 with 15 Axes>

# %%
ICAComponents.exclude = [1,2]

# %%
rawEEG_ICA = ICAComponents.apply(rawEEG)
# Out:
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 2 ICA components
#     Projecting back using 19 PCA components

# %%
rawEEG_ICA.plot()
# Out:
# <MNEBrowseFigure size 1920x1017 with 4 Axes>

# %%
import matplotlib.pyplot as plt

# %%
rawEEG.plot()
plt.show()
# Out:
# Channels marked as bad:
# none
